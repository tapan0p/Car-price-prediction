# %%
import pandas as pd
df = pd.read_csv('../Dataset/preprocessed_data.csv').drop(columns=['Unnamed: 0'])
df
# Out:
#                     Car Name  Year  Distance  Owner    Fuel Location  \
# 0            Maruti S PRESSO  2022      3878      1  PETROL    HR-98
# 1              Hyundai Xcent  2018     32041      1  PETROL    TN-22
# 2                Tata Safari  2021     96339      1  DIESEL    TS-08
# 3       Maruti Vitara Brezza  2019     51718      1  DIESEL    WB-24
# 4                 Tata Tiago  2021     19811      1  PETROL    HR-51
# ...                      ...   ...       ...    ...     ...      ...
# 8006          Datsun Redi Go  2018     11500      1  PETROL    MH-01
# 8007            Toyota YARIS  2018     73393      2  PETROL    KA-03
# 8008         Volkswagen Ameo  2016     83810      2  PETROL    UP-78
# 8009  Hyundai GRAND I10 NIOS  2019     39162      1  PETROL    CH-01
# 8010              Tata TIGOR  2022     82009      2  PETROL    MH-02
#
#           Drive       Type    Price
# 0        Manual  HatchBack   514000
# 1        Manual      Sedan   674000
# ...

# %%
categorical_columns=['Car Name', 'Fuel', 'Location', 'Drive' , 'Type','Owner']
mapping = {}
for column in categorical_columns:
    mapping[column] = df[column].unique()
mapping
# Out:
# {'Car Name': array(['Maruti S PRESSO', 'Hyundai Xcent', 'Tata Safari',
#         'Maruti Vitara Brezza', 'Tata Tiago', 'Maruti Swift',
#         'Hyundai i20', 'Renault Kwid', 'Hyundai Grand i10', 'Maruti IGNIS',
#         'Honda Brio', 'Hyundai Elite i20', 'Honda City', 'Maruti Baleno',
#         'Honda WR-V', 'Honda Amaze', 'Maruti Alto 800', 'Maruti Celerio',
#         'Ford Ecosport', 'Maruti Ciaz', 'Datsun Redi Go', 'Tata TIAGO NRG',
#         'Hyundai Santro Xing', 'Ford FREESTYLE', 'Maruti Dzire',
#         'Maruti Alto', 'Hyundai NEW SANTRO', 'Maruti Alto K10',
#         'Ford Endeavour', 'Maruti Swift Dzire', 'Maruti Wagon R 1.0',
#         'Hyundai GRAND I10 NIOS', 'Maruti Celerio X',
#         'Toyota URBAN CRUISER', 'Mahindra XUV500', 'Hyundai Verna',
#         'Hyundai VENUE', 'Tata NEXON', 'Mahindra KUV 100 NXT',
#         'Toyota YARIS', 'Mahindra XUV 3OO', 'Renault TRIBER',
#         'Hyundai Tucson New', 'Mahindra TUV300', 'Toyota Glanza',
# ...
